# %%
# Import the libraries
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
import copy
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# Technical indicator library
import talib as ta

import datetime

from itertools import chain, combinations, product


import threading
import math

# %%
Df = pd.read_csv("./WIN$N_M15.csv",delimiter=",",decimal=".",dtype = {'Open': np.double, 'High': np.double, 'Low': np.double, 'Close': np.double})

Df = Df.dropna()
Df['Time'] = pd.to_datetime(Df['Time'],dayfirst=True)
start = datetime.datetime.now()


# we need to rename the columns since the SA lib uses a diferent name
Df.rename(columns={'Time': 'time', 'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Volume': 'volume'}, inplace=True)
rates = Df.to_dict("records")
# let's change back the column's name
Df.rename(columns={'time': 'Time', 'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'}, inplace=True)
Df['Time'] = pd.to_datetime(Df['Time'],dayfirst=True)



Df = Df.dropna()
# Prediction horizon (candles)
pred_horizon = 2

# Create a column 'Fut_Ret' with the calculation of returns
Df['Ret'] = (Df['Open'].shift(-pred_horizon)-Df['Open'])/Df['Open']

# # Create n columns and assign
# for i in range(1, n):
#     Df['return%i' % i] = Df['Ret'].shift(i)

Df = Df.dropna()

t = .8
split = int(t*len(Df))

# Create a column by name, 'Signal' and initialize with 0
Df['Signal']=0

# Assign a value of 1 to 'Signal' column for the quantile with highest returns
Df.loc[Df['Ret']>Df['Ret'][:split].quantile(q=0.66),'Signal']=1

# Assign a value of -1 to 'Signal' column for the quantile with lowest returns
Df.loc[Df['Ret']<Df['Ret'][:split].quantile(q=0.33),'Signal']=-1
# # # It is necessary for daytrade only. If you are using daily candles, please comment the lines below

# # Assign a value of 0 to 'Signal' column after 17h
Df.loc[(Df['Time'].dt.hour>16), 'Signal']=0

# Assign a value of 0 to 'Ret' column after 17h
Df.loc[(Df['Time'].dt.hour>16), 'Ret']=0

i_high = np.array(Df['High'].shift(1))
i_low = np.array(Df['Low'].shift(1))
i_close = np.array(Df['Close'].shift(1))
i_volume = np.array(Df['Volume'].shift(1))

indicators_groups = ['RSI', 'STOCH_k STOCH_D', 'MACD MACDSIGNAL', 'ADX', 'CCI', 'MFI', 'WILLR', 'TRIX']   

Df['RSI'] = ta.RSI(i_close)
Df['STOCH_k'], Df['STOCH_D'] = ta.STOCH(i_high, i_low, i_close)
Df['MACD'], Df['MACDSIGNAL'], _ = ta.MACD(i_close)
Df['ADX'] = ta.ADX(i_high, i_low, i_close)
Df['CCI'] = ta.CCI(i_high, i_low, i_close)
Df['MFI'] = ta.MFI(i_high, i_low, i_close, i_volume)
Df['WILLR'] = ta.WILLR(i_high, i_low, i_close)
Df['TRIX'] = ta.TRIX(i_close)

Df = Df.dropna()


indicators = set(list(' '.join(indicators_groups).split()))

def sa(_params):
    diff = list(indicators - set(_params))

    return Df.drop(diff, axis=1).copy()

Df
# Out:
#                      Time      Open      High       Low     Close  Volume  \
# 89    2014-02-17 13:15:00   48485.0   48570.0   48455.0   48550.0    2270
# 90    2014-02-17 13:30:00   48550.0   48555.0   48510.0   48530.0     730
# 91    2014-02-17 13:45:00   48535.0   48550.0   48515.0   48540.0     529
# 92    2014-02-17 14:00:00   48540.0   48555.0   48490.0   48510.0     905
# 93    2014-02-17 14:15:00   48510.0   48520.0   48485.0   48500.0     641
# ...                   ...       ...       ...       ...       ...     ...
# 77370 2022-09-20 11:30:00  112975.0  113020.0  112510.0  112790.0  610555
# 77371 2022-09-20 11:45:00  112785.0  112910.0  112615.0  112855.0  417011
# 77372 2022-09-20 12:00:00  112855.0  113050.0  112655.0  112895.0  450579
# 77373 2022-09-20 12:15:00  112895.0  113175.0  112815.0  112935.0  447571
# 77374 2022-09-20 12:30:00  112935.0  113160.0  112875.0  113080.0  317564
#
#             Ret  Signal        RSI    STOCH_k    STOCH_D        MACD  \
# 89     0.001031       0  37.052700  17.758985  16.953253  -27.783553
# 90    -0.000206       0  41.907838  23.649187  19.206112  -34.377441
# 91    -0.000515       0  40.863452  25.811117  22.406430  -40.747268
# 92    -0.001030      -1  41.646498  42.780814  30.747039  -44.475796
# 93    -0.001752      -1  39.937966  45.185185  37.925705  -49.283324
# ...         ...     ...        ...        ...        ...         ...
# 77370 -0.001062      -1  58.756302  57.088480  43.093805  244.550199
# 77371  0.000975       0  54.993227  65.143814  54.436136  228.073578
# 77372  0.000709       0  56.058090  64.589166  62.273820  217.750601
# 77373  0.001639       1  56.736464  57.595783  62.442921  210.372194
# 77374  0.003099       1  57.443979  58.770216  60.318388  205.384869
#
#        MACDSIGNAL        ADX         CCI        MFI      WILLR      TRIX
# 89       8.594372  14.007068 -181.430446  35.426562 -91.954023  0.019719
# 90       0.000010  15.370493 -127.816853  41.116284 -77.011494  0.018834
# 91      -8.149446  16.636530  -97.363328  44.742493 -81.609195  0.017901
# 92     -15.414716  17.812136  -79.083847  42.435021 -79.310345  0.016942
# 93     -22.188437  19.114009  -76.681614  47.051874 -86.206897  0.015953
# ...           ...        ...         ...        ...        ...       ...
# 77370  321.804110  34.598051   14.047525  63.736266 -39.325843  0.041710
# 77371  303.058004  33.264575  -17.107605  57.907672 -53.183521  0.041664
# 77372  285.996523  32.026348   -3.633303  58.728479 -48.314607  0.041544
# 77373  270.871657  31.205506   33.585859  60.355205 -43.629344  0.041366
# 77374  257.774300  30.727301   96.312057  62.176586 -39.370079  0.041139
#
# [77286 rows x 18 columns]

# %%
def generate_indicators():
    s = list(indicators_groups)
    _result = list(chain.from_iterable(combinations(s, r) for r in range(1, len(s)+1)))
    return list(map(lambda x: list(' '.join(x).split()), _result))
    
def CalculateMetrics(_returns, _y_pred, _dates, optimize=False, prediction_horizon=1, type_='percentual'):
    #Receive the dates, predictions and returns, apply a simple trading strategy (exit position after n candles, without tp and sl), and show the results and graph"""

    #--- get the returns if we follow the strategy (follow the prediction signals) - it is equivalent to buying or selling according to the signal, and keep the position for n candles. We can have multiple positions at the same time, without sl and tp
    strategy_returns=[_y_pred[i] * _returns[i] for i in range(0, len(_y_pred))]

    #--- get the cumulative return of our strategy - increasing position - juros composto
    strategy_accumulated_prod = 1
    for i in range(1, len(strategy_returns)):
        strategy_accumulated_prod *= (strategy_returns[i]+1)
    strategy_accumulated_prod -= 1

    #--- get the cumulative return of our strategy
    strategy_accumulated = copy.copy(strategy_returns)
    for i in range(1, len(strategy_accumulated)):
        strategy_accumulated[i] = strategy_accumulated[i-1] + strategy_returns[i]

    #--- get the cumulative return of the asset - where we buy only, at every candle, and keeps the position opened for n candles
    asset_accumulated = copy.copy(_returns)
    for i in range(1, len(asset_accumulated)):
        asset_accumulated[i] = asset_accumulated[i-1] + _returns[i]


    #--- get the cumulative loss of our strategy - draw down
    strategy_drawdown = copy.copy(strategy_returns)
    for i in range(1, len(strategy_drawdown)):
        strategy_drawdown[i] = (strategy_drawdown[i-1] + strategy_returns[i] if strategy_drawdown[i-1] + strategy_returns[i] < 0 else 0)

    drawdown_max = np.min(np.array(strategy_drawdown))
    drawdown_mean = np.mean(np.array(strategy_drawdown))
    total_return = strategy_accumulated[-1]
    total_days = len(list(set([date.strftime("%Y-%m-%d") for date in _dates])))
    total_months = total_days / 21
    monthly_return = (total_return/total_months if total_months>0 else 0)
    drawdown_max_by_monthly_return = (-drawdown_max/monthly_return if monthly_return != 0 else 0)
    drawdown_mean_by_monthly_return = (-drawdown_mean/monthly_return if monthly_return != 0 else 0)


    #--- calculating a few metrics

    if optimize:
        e = []
        for i,pred in enumerate(_y_pred):
            if _y_pred[max(0, i - prediction_horizon)] != pred: e.append(abs(pred))
        entries = np.sum(np.array(e))
    else:
        entries = np.sum(np.array([abs(pred) for pred in _y_pred]))
        entries_buy = int(np.sum(np.array([abs(pred) for pred in _y_pred if pred > 0])))
        entries_sell = int(np.sum(np.array([abs(pred) for pred in _y_pred if pred < 0])))
    total_return = strategy_accumulated[-1]
    if entries>0:
        return_per_entry = total_return / entries
    else:
        return_per_entry = 0

    poss = sum([1 for return_ in strategy_returns if return_ > 0])
    negs = sum([1 for return_ in strategy_returns if return_ < 0])
    success = (poss+1) / (poss + negs+2)

    poss_ = sum([return_ for return_ in strategy_returns if return_ > 0])
    negs_ = sum([return_ for return_ in strategy_returns if return_ < 0])
    profitFactor = -((poss_+0.000001)/(negs_+0.000001))
    return [round(total_return*100,4), entries, round(return_per_entry*100,4), round(success*100,2), round(profitFactor,2), total_days, round(total_months,4), round(monthly_return*100,4), round(drawdown_max*100,4), round(drawdown_mean*100,4), entries_buy, entries_sell]


def PreviousCalculateMetrics(returns,y_pred,dates,optimize=False,prediction_horizon=1,type_='percentual'):
    #Receive the dates, predictions and returns, apply a simple trading strategy (exit position after n candles, without tp and sl), and show the results and graph"""

    #--- get the returns if we follow the strategy (follow the prediction signals) - it is equivalent to buying or selling according to the signal, and keep the position for n candles. We can have multiple positions at the same time, without sl and tp
    strategy_returns=[y_pred[i]*returns[i] for i in range(0,len(y_pred))]

    #--- get the cumulative return of our strategy - increasing position - juros composto
    strategy_accumulated_prod = 1
    for i in range(1, len(strategy_returns)):
        strategy_accumulated_prod *= (strategy_returns[i]+1)
    strategy_accumulated_prod -= 1

    #--- get the cumulative return of our strategy
    strategy_accumulated = copy.copy(strategy_returns)
    for i in range(1, len(strategy_accumulated)):
        strategy_accumulated[i] = strategy_accumulated[i-1] + strategy_returns[i]

    #--- get the cumulative return of the asset - where we buy only, at every candle, and keeps the position opened for n candles
    asset_accumulated = copy.copy(returns)
    for i in range(1, len(asset_accumulated)):
        asset_accumulated[i] = asset_accumulated[i-1] + returns[i]


    #--- get the cumulative loss of our strategy - draw down
    strategy_drawdown = copy.copy(strategy_returns)
    for i in range(1, len(strategy_drawdown)):
        strategy_drawdown[i] = (strategy_drawdown[i-1] + strategy_returns[i] if strategy_drawdown[i-1] + strategy_returns[i] < 0 else 0)

    drawdown_max = np.min(np.array(strategy_drawdown))
    drawdown_mean = np.mean(np.array(strategy_drawdown))
    total_return = strategy_accumulated[-1]
    total_days = len(list(set([date.strftime("%Y-%m-%d") for date in dates])))
    total_months = total_days / 21
    monthly_return = (total_return/total_months if total_months>0 else 0)
    drawdown_max_by_monthly_return = (-drawdown_max/monthly_return if monthly_return != 0 else 0)
    drawdown_mean_by_monthly_return = (-drawdown_mean/monthly_return if monthly_return != 0 else 0)


    #--- calculating a few metrics

    if optimize:
        e = []
        for i,pred in enumerate(y_pred):
            if y_pred[max(0,i-prediction_horizon)] != pred: e.append(abs(pred))
        entries = np.sum(np.array(e))
    else:
        entries = np.sum(np.array([abs(pred) for pred in y_pred]))
        entries_buy = int(np.sum(np.array([abs(pred) for pred in y_pred if pred>0])))
        entries_sell = int(np.sum(np.array([abs(pred) for pred in y_pred if pred<0])))
    total_return = strategy_accumulated[-1]
    if entries>0:
        return_per_entry = total_return / entries
    else:
        return_per_entry = 0

    poss = sum([1 for return_ in strategy_returns if return_ > 0])
    negs = sum([1 for return_ in strategy_returns if return_ < 0])
    success = (poss+1) / (poss + negs+2)

    poss_ = sum([return_ for return_ in strategy_returns if return_ > 0])
    negs_ = sum([return_ for return_ in strategy_returns if return_ < 0])
    profitFactor = -((poss_+0.000001)/(negs_+0.000001))

    if type_ == 'percentual':
        print(
            "\n \tTotal return: ",round(total_return*100,4),"%",
            "\n \tEntries: ", entries,
            "\n \tReturn per entry: ", round(return_per_entry*100,4),"%",
            "\n \tSuccess: ", round(success*100,2),"%",
            "\n \tRatio: ", round(profitFactor,2),
            "\n \tTotal of days: ", total_days,
            "\n \tTotal of months: ", round(total_months,4),
            "\n \tMonthly return: ", round(monthly_return*100,4),"%",
            "\n \tMax drawdown: ", round(drawdown_max*100,4),"%",
            "\n \tMean drawdown: ", round(drawdown_mean*100,4),"%",
            "\n \tBuy signals", entries_buy,
            "\n \tSell signals", entries_sell,
        )
    else:
        print(
            "\n \tTotal return: ",round(total_return,4),
            "\n \tEntries: ", entries,
            "\n \tReturn per entry: ", round(return_per_entry,4),
            "\n \tSuccess: ", round(success*100,2),"%",
            "\n \tRatio: ", round(profitFactor,2),
            "\n \tTotal of days: ", total_days,
            "\n \tTotal of months: ", round(total_months,4),
            "\n \tMonthly return: ", round(monthly_return,4),
            "\n \tMax drawdown: ", round(drawdown_max,4),
            "\n \tMean drawdown: ", round(drawdown_mean,4),
            "\n \tBuy signals", entries_buy,
            "\n \tSell signals", entries_sell,
        )


def execute_test(indicators__, result__, count__, lock__, print_result = False):
    count = count__
    for params in indicators__:
        try:
            lock__.acquire()
            print(str(count + 1) + " starting " + ','.join(params))
            lock__.release()
            df = sa(params)

            X = df.drop(['Ret',"Time","Signal", 'Close', 'Signal', 'High',
                         'Low', 'Open', 'Volume', 'Ret'], axis=1)

            # Create a variable which contains all the 'Signal' values
            y = df['Signal']

            cls = QuadraticDiscriminantAnalysis()

            ss1 = StandardScaler()

            # Pass the scaled train data to the SVC classifier
            cls.fit(ss1.fit_transform(X.iloc[:split]),y.iloc[:split])

            # Pass the test data to the predict function and store the values into 'y_predict'
            y_predict = cls.predict(ss1.transform(X.iloc[split:]))

            # This is an alternative approach to generate the predictions.
            # It uses the same method used in the ML framework, generates predictions based on a list of probability
            # Please, uncomment the last line of this code block if you want to use it

            y_prob = cls.predict_proba(ss1.transform(X.iloc[split:]))

            # Initiate a column by name, 'Pred_Signal' and assign 0 to it
            df['Pred_Signal'] = 0

            # Save the predicted values for the train data
            # df.iloc[:split,df.columns.get_loc('Pred_Signal')] = pd.Series(cls.predict(ss1.transform(X.iloc[:split])).tolist())
            df.iloc[:split,df.columns.get_loc('Pred_Signal')] =cls.predict(ss1.transform(X.iloc[:split]))

            # Save the predicted values for the test data
            df.iloc[split:,df.columns.get_loc('Pred_Signal')] = y_predict

            df['Profit'] = df['Pred_Signal']*df['Ret']

            df["Test_Set"] = 0
            df.loc[split:,"Test_Set"] = 1
            # df.to_csv("output_pred.csv")

            df.to_csv("output_pred.csv")
            # Calculate strategy returns and store them in 'Ret1' column
            df['Ret1'] = df['Ret'] * df['Pred_Signal']

            # Strategy Metrics
            returns = list(df['Ret'][split:])
            y_pred = list(df['Pred_Signal'][split:])
            dates = list(df['Time'][split:])
            metrics_test = CalculateMetrics(returns,y_pred,dates,type_='percentual')

            # Strategy Metrics
            returns = list(df['Ret'][:split])
            y_pred = list(df['Pred_Signal'][:split])
            dates = list(df['Time'][:split])
            metrics_training = CalculateMetrics(returns, y_pred, dates, type_='percentual')

            ok = [','.join(params)] + metrics_training + metrics_test
            lock__.acquire()
            result__.append(ok)
            if print_result:
                # Strategy Metrics
                returns = list(df['Ret'][split:])
                y_pred = list(df['Pred_Signal'][split:])
                dates = list(df['Time'][split:])
                print("\nStrategy results %: ")
                PreviousCalculateMetrics(returns,y_pred,dates,type_='percentual')

                returns_absolute = list((df['Ret']*df['Open'])[split:])
                print("\nStrategy results: ")
                PreviousCalculateMetrics(returns_absolute,y_pred,dates,type_='points')

                df.set_index("Time", inplace=True)
                # Plot the strategy returns in the test period
                plt.figure(figsize=(10,10))
                # plt.plot(((df['Ret'][:split]+1).cumprod()-1),color='r',label='Mini-índice')
                # plt.plot(((df['Ret1'][:split]+1).cumprod()-1),color='g',label='Estratégia')
                plt.plot(((df['Ret'][:split]).cumsum()),color='r',label='Baseline')
                plt.plot(((df['Ret1'][:split]).cumsum()),color='g',label='estratégia')
                plt.plot((((df['Open'].shift(-1) - df['Open']) / df['Open'])[:split] + 1).cumprod() - 1, color='b', label='winfut')
                plt.legend()
                plt.xticks(rotation=-45)
                plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
                plt.show()


                # Plot the strategy returns in the test period
                plt.figure(figsize=(10,10))
                # plt.plot(((df['Ret'][split:]+1).cumprod()-1),color='r',label='Mini-índice')
                # plt.plot(((df['Ret1'][split:]+1).cumprod()-1),color='g',label='Estratégia')
                plt.plot(((df['Ret'][split:]).cumsum()),color='r',label='Baseline')
                plt.plot(((df['Ret1'][split:]).cumsum()),color='g',label='estratégia-teste')
                plt.plot((((df['Open'].shift(-1) - df['Open']) / df['Open'])[split:] + 1).cumprod() - 1, color='b', label='winfut')
                plt.legend()
                plt.xticks(rotation=-45)
                plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
                plt.show()
            lock__.release()
            count += 1
            lock__.acquire()
            print(str(count) + ' finishing ' + ','.join(params))
            lock__.release()
        except Exception as e:
            count += 1
            lock__.acquire()
            print(str(count) + 'ERROR ERROR ERROR ' + ','.join(params))
            print(e)
            lock__.release()



def runFullTest(params_, csv_name):
    lock = threading.Lock()
    results = []
    threads = [None] * 2
    slice_size = math.ceil(float(len(params_)) / float(len(threads)))

    for i in range(len(threads)):
        params = params_[(i * slice_size):((i + 1) * slice_size)]
        threads[i] = threading.Thread(target=execute_test, args=(params, results, i * slice_size, lock))
        threads[i].start()

    for i in range(len(threads)):
        threads[i].join()
    columns_training = ['Total return (training)', 'Entries (training)', 'Return per entry (training)', 'Success (training)', 'Ratio (training)', 'Total of days (training)', 'Total of months (training)', 'Monthly return (training)', 'Max drawdown (training)', 'Mean drawdown (training)', 'Buy signals (training)', 'Sell signals (training)']
    columns_test = ['Total return (test)', 'Entries (test)', 'Return per entry (test)', 'Success (test)', 'Ratio (test)', 'Total of days (test)', 'Total of months (test)', 'Monthly return (test)', 'Max drawdown (test)', 'Mean drawdown (test)', 'Buy signals (test)', 'Sell signals (test)']

    resultsDf = pd.DataFrame(results, columns=['indicators'] + columns_training + columns_test)
    resultsDf.to_csv(f'{csv_name}.csv', index=False)
    return resultsDf

# %%
indicators_combinations = generate_indicators()

runFullTest(indicators_combinations, 'indicators-test')
# Out:
# 1 starting RSI
# 129 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI
# 1 finishing RSI
# 2 starting STOCH_k,STOCH_D
# 129 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI
# 130 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR
# 2 finishing STOCH_k,STOCH_D
# 3 starting MACD,MACDSIGNAL
# 130 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR
# 131 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,TRIX
# 3 finishing MACD,MACDSIGNAL
# 4 starting ADX
# 4 finishing ADX
# 5 starting CCI
# 131 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,TRIX
# 132 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI
# 5 finishing CCI
# 6 starting MFI
# 132 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI
# 133 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR
# 6 finishing MFI
# 7 starting WILLR
# 133 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR
# 134 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,TRIX
# 7 finishing WILLR
# 8 starting TRIX
# 8 finishing TRIX
# 9 starting RSI,STOCH_k,STOCH_D
# 134 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,TRIX
# 135 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR
# 9 finishing RSI,STOCH_k,STOCH_D
# 10 starting RSI,MACD,MACDSIGNAL
# 135 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR
# 136 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,TRIX
# 10 finishing RSI,MACD,MACDSIGNAL
# 11 starting RSI,ADX
# 136 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,TRIX
# 137 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR,TRIX
# 11 finishing RSI,ADX
# 12 starting RSI,CCI
# 137 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR,TRIX
# 138 starting STOCH_k,STOCH_D,ADX,CCI,MFI
# 12 finishing RSI,CCI
# 13 starting RSI,MFI
# 138 finishing STOCH_k,STOCH_D,ADX,CCI,MFI
# 139 starting STOCH_k,STOCH_D,ADX,CCI,WILLR
# 13 finishing RSI,MFI
# 14 starting RSI,WILLR
# 139 finishing STOCH_k,STOCH_D,ADX,CCI,WILLR
# 140 starting STOCH_k,STOCH_D,ADX,CCI,TRIX
# 14 finishing RSI,WILLR
# 15 starting RSI,TRIX
# 140 finishing STOCH_k,STOCH_D,ADX,CCI,TRIX
# 141 starting STOCH_k,STOCH_D,ADX,MFI,WILLR
# 15 finishing RSI,TRIX
# 16 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL
# 16 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL
# 17 starting STOCH_k,STOCH_D,ADX
# 141 finishing STOCH_k,STOCH_D,ADX,MFI,WILLR
# 142 starting STOCH_k,STOCH_D,ADX,MFI,TRIX
# 17 finishing STOCH_k,STOCH_D,ADX
# 18 starting STOCH_k,STOCH_D,CCI
# 142 finishing STOCH_k,STOCH_D,ADX,MFI,TRIX
# 143 starting STOCH_k,STOCH_D,ADX,WILLR,TRIX
# 18 finishing STOCH_k,STOCH_D,CCI
# 19 starting STOCH_k,STOCH_D,MFI
# 143 finishing STOCH_k,STOCH_D,ADX,WILLR,TRIX
# 144 starting STOCH_k,STOCH_D,CCI,MFI,WILLR
# 19 finishing STOCH_k,STOCH_D,MFI
# 20 starting STOCH_k,STOCH_D,WILLR
# 144 finishing STOCH_k,STOCH_D,CCI,MFI,WILLR
# 145 starting STOCH_k,STOCH_D,CCI,MFI,TRIX
# 20 finishing STOCH_k,STOCH_D,WILLR
# 21 starting STOCH_k,STOCH_D,TRIX
# 145 finishing STOCH_k,STOCH_D,CCI,MFI,TRIX
# 146 starting STOCH_k,STOCH_D,CCI,WILLR,TRIX
# 21 finishing STOCH_k,STOCH_D,TRIX
# 22 starting MACD,MACDSIGNAL,ADX
# 146 finishing STOCH_k,STOCH_D,CCI,WILLR,TRIX
# 147 starting STOCH_k,STOCH_D,MFI,WILLR,TRIX
# 22 finishing MACD,MACDSIGNAL,ADX
# 23 starting MACD,MACDSIGNAL,CCI
# 23 finishing MACD,MACDSIGNAL,CCI
# 24 starting MACD,MACDSIGNAL,MFI
# 147 finishing STOCH_k,STOCH_D,MFI,WILLR,TRIX
# 148 starting MACD,MACDSIGNAL,ADX,CCI,MFI
# 24 finishing MACD,MACDSIGNAL,MFI
# 25 starting MACD,MACDSIGNAL,WILLR
# 148 finishing MACD,MACDSIGNAL,ADX,CCI,MFI
# 149 starting MACD,MACDSIGNAL,ADX,CCI,WILLR
# 25 finishing MACD,MACDSIGNAL,WILLR
# 26 starting MACD,MACDSIGNAL,TRIX
# 149 finishing MACD,MACDSIGNAL,ADX,CCI,WILLR
# 150 starting MACD,MACDSIGNAL,ADX,CCI,TRIX
# 26 finishing MACD,MACDSIGNAL,TRIX
# 27 starting ADX,CCI
# 150 finishing MACD,MACDSIGNAL,ADX,CCI,TRIX
# 151 starting MACD,MACDSIGNAL,ADX,MFI,WILLR
# 27 finishing ADX,CCI
# 28 starting ADX,MFI
# 151 finishing MACD,MACDSIGNAL,ADX,MFI,WILLR
# 152 starting MACD,MACDSIGNAL,ADX,MFI,TRIX
# 28 finishing ADX,MFI
# 29 starting ADX,WILLR
# 29 finishing ADX,WILLR
# 30 starting ADX,TRIX
# 152 finishing MACD,MACDSIGNAL,ADX,MFI,TRIX
# 153 starting MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 30 finishing ADX,TRIX
# 31 starting CCI,MFI
# 153 finishing MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 154 starting MACD,MACDSIGNAL,CCI,MFI,WILLR
# 31 finishing CCI,MFI
# 32 starting CCI,WILLR
# 154 finishing MACD,MACDSIGNAL,CCI,MFI,WILLR
# 155 starting MACD,MACDSIGNAL,CCI,MFI,TRIX
# 32 finishing CCI,WILLR
# 33 starting CCI,TRIX
# 155 finishing MACD,MACDSIGNAL,CCI,MFI,TRIX
# 156 starting MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 33 finishing CCI,TRIX
# 34 starting MFI,WILLR
# 156 finishing MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 157 starting MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 34 finishing MFI,WILLR
# 35 starting MFI,TRIX
# 157 finishing MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 158 starting ADX,CCI,MFI,WILLR
# 35 finishing MFI,TRIX
# 36 starting WILLR,TRIX
# 36 finishing WILLR,TRIX
# 37 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL
# 158 finishing ADX,CCI,MFI,WILLR
# 159 starting ADX,CCI,MFI,TRIX
# 37 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL
# 38 starting RSI,STOCH_k,STOCH_D,ADX
# 159 finishing ADX,CCI,MFI,TRIX
# 160 starting ADX,CCI,WILLR,TRIX
# 38 finishing RSI,STOCH_k,STOCH_D,ADX
# 39 starting RSI,STOCH_k,STOCH_D,CCI
# 160 finishing ADX,CCI,WILLR,TRIX
# 161 starting ADX,MFI,WILLR,TRIX
# 39 finishing RSI,STOCH_k,STOCH_D,CCI
# 40 starting RSI,STOCH_k,STOCH_D,MFI
# 161 finishing ADX,MFI,WILLR,TRIX
# 162 starting CCI,MFI,WILLR,TRIX
# 40 finishing RSI,STOCH_k,STOCH_D,MFI
# 41 starting RSI,STOCH_k,STOCH_D,WILLR
# 162 finishing CCI,MFI,WILLR,TRIX
# 163 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI
# 41 finishing RSI,STOCH_k,STOCH_D,WILLR
# 42 starting RSI,STOCH_k,STOCH_D,TRIX
# 163 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI
# 164 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI
# 42 finishing RSI,STOCH_k,STOCH_D,TRIX
# 43 starting RSI,MACD,MACDSIGNAL,ADX
# 164 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI
# 165 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR
# 43 finishing RSI,MACD,MACDSIGNAL,ADX
# 44 starting RSI,MACD,MACDSIGNAL,CCI
# 165 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR
# 166 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,TRIX
# 44 finishing RSI,MACD,MACDSIGNAL,CCI
# 45 starting RSI,MACD,MACDSIGNAL,MFI
# 166 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,TRIX
# 167 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI
# 45 finishing RSI,MACD,MACDSIGNAL,MFI
# 46 starting RSI,MACD,MACDSIGNAL,WILLR
# 167 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI
# 168 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR
# 46 finishing RSI,MACD,MACDSIGNAL,WILLR
# 47 starting RSI,MACD,MACDSIGNAL,TRIX
# 168 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR
# 169 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,TRIX
# 47 finishing RSI,MACD,MACDSIGNAL,TRIX
# 48 starting RSI,ADX,CCI
# 169 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,TRIX
# 170 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR
# 48 finishing RSI,ADX,CCI
# 49 starting RSI,ADX,MFI
# 170 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR
# 171 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,TRIX
# 49 finishing RSI,ADX,MFI
# 50 starting RSI,ADX,WILLR
# 171 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,TRIX
# 172 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR,TRIX
# 50 finishing RSI,ADX,WILLR
# 51 starting RSI,ADX,TRIX
# 51 finishing RSI,ADX,TRIX
# 52 starting RSI,CCI,MFI
# 172 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR,TRIX
# 173 starting RSI,STOCH_k,STOCH_D,ADX,CCI,MFI
# 52 finishing RSI,CCI,MFI
# 53 starting RSI,CCI,WILLR
# 173 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,MFI
# 174 starting RSI,STOCH_k,STOCH_D,ADX,CCI,WILLR
# 53 finishing RSI,CCI,WILLR
# 54 starting RSI,CCI,TRIX
# 174 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,WILLR
# 175 starting RSI,STOCH_k,STOCH_D,ADX,CCI,TRIX
# 54 finishing RSI,CCI,TRIX
# 55 starting RSI,MFI,WILLR
# 175 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,TRIX
# 176 starting RSI,STOCH_k,STOCH_D,ADX,MFI,WILLR
# 55 finishing RSI,MFI,WILLR
# 56 starting RSI,MFI,TRIX
# 176 finishing RSI,STOCH_k,STOCH_D,ADX,MFI,WILLR
# 177 starting RSI,STOCH_k,STOCH_D,ADX,MFI,TRIX
# 56 finishing RSI,MFI,TRIX
# 57 starting RSI,WILLR,TRIX
# 57 finishing RSI,WILLR,TRIX
# 58 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX
# 177 finishing RSI,STOCH_k,STOCH_D,ADX,MFI,TRIX
# 178 starting RSI,STOCH_k,STOCH_D,ADX,WILLR,TRIX
# 58 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX
# 59 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI
# 178 finishing RSI,STOCH_k,STOCH_D,ADX,WILLR,TRIX
# 179 starting RSI,STOCH_k,STOCH_D,CCI,MFI,WILLR
# 59 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI
# 60 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI
# 179 finishing RSI,STOCH_k,STOCH_D,CCI,MFI,WILLR
# 180 starting RSI,STOCH_k,STOCH_D,CCI,MFI,TRIX
# 60 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI
# 61 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR
# 180 finishing RSI,STOCH_k,STOCH_D,CCI,MFI,TRIX
# 181 starting RSI,STOCH_k,STOCH_D,CCI,WILLR,TRIX
# 61 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR
# 62 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,TRIX
# 181 finishing RSI,STOCH_k,STOCH_D,CCI,WILLR,TRIX
# 182 starting RSI,STOCH_k,STOCH_D,MFI,WILLR,TRIX
# 62 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,TRIX
# 63 starting STOCH_k,STOCH_D,ADX,CCI
# 182 finishing RSI,STOCH_k,STOCH_D,MFI,WILLR,TRIX
# 183 starting RSI,MACD,MACDSIGNAL,ADX,CCI,MFI
# 63 finishing STOCH_k,STOCH_D,ADX,CCI
# 64 starting STOCH_k,STOCH_D,ADX,MFI
# 183 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,MFI
# 184 starting RSI,MACD,MACDSIGNAL,ADX,CCI,WILLR
# 64 finishing STOCH_k,STOCH_D,ADX,MFI
# 65 starting STOCH_k,STOCH_D,ADX,WILLR
# 184 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,WILLR
# 185 starting RSI,MACD,MACDSIGNAL,ADX,CCI,TRIX
# 65 finishing STOCH_k,STOCH_D,ADX,WILLR
# 66 starting STOCH_k,STOCH_D,ADX,TRIX
# 185 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,TRIX
# 186 starting RSI,MACD,MACDSIGNAL,ADX,MFI,WILLR
# 66 finishing STOCH_k,STOCH_D,ADX,TRIX
# 67 starting STOCH_k,STOCH_D,CCI,MFI
# 186 finishing RSI,MACD,MACDSIGNAL,ADX,MFI,WILLR
# 187 starting RSI,MACD,MACDSIGNAL,ADX,MFI,TRIX
# 67 finishing STOCH_k,STOCH_D,CCI,MFI
# 68 starting STOCH_k,STOCH_D,CCI,WILLR
# 187 finishing RSI,MACD,MACDSIGNAL,ADX,MFI,TRIX
# 188 starting RSI,MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 68 finishing STOCH_k,STOCH_D,CCI,WILLR
# 69 starting STOCH_k,STOCH_D,CCI,TRIX
# 188 finishing RSI,MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 189 starting RSI,MACD,MACDSIGNAL,CCI,MFI,WILLR
# 69 finishing STOCH_k,STOCH_D,CCI,TRIX
# 70 starting STOCH_k,STOCH_D,MFI,WILLR
# 189 finishing RSI,MACD,MACDSIGNAL,CCI,MFI,WILLR
# 190 starting RSI,MACD,MACDSIGNAL,CCI,MFI,TRIX
# 70 finishing STOCH_k,STOCH_D,MFI,WILLR
# 71 starting STOCH_k,STOCH_D,MFI,TRIX
# 190 finishing RSI,MACD,MACDSIGNAL,CCI,MFI,TRIX
# 191 starting RSI,MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 71 finishing STOCH_k,STOCH_D,MFI,TRIX
# 72 starting STOCH_k,STOCH_D,WILLR,TRIX
# 191 finishing RSI,MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 192 starting RSI,MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 72 finishing STOCH_k,STOCH_D,WILLR,TRIX
# 73 starting MACD,MACDSIGNAL,ADX,CCI
# 192 finishing RSI,MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 193 starting RSI,ADX,CCI,MFI,WILLR
# 73 finishing MACD,MACDSIGNAL,ADX,CCI
# 74 starting MACD,MACDSIGNAL,ADX,MFI
# 193 finishing RSI,ADX,CCI,MFI,WILLR
# 194 starting RSI,ADX,CCI,MFI,TRIX
# 74 finishing MACD,MACDSIGNAL,ADX,MFI
# 75 starting MACD,MACDSIGNAL,ADX,WILLR
# 194 finishing RSI,ADX,CCI,MFI,TRIX
# 195 starting RSI,ADX,CCI,WILLR,TRIX
# 75 finishing MACD,MACDSIGNAL,ADX,WILLR
# 76 starting MACD,MACDSIGNAL,ADX,TRIX
# 195 finishing RSI,ADX,CCI,WILLR,TRIX
# 196 starting RSI,ADX,MFI,WILLR,TRIX
# 76 finishing MACD,MACDSIGNAL,ADX,TRIX
# 77 starting MACD,MACDSIGNAL,CCI,MFI
# 196 finishing RSI,ADX,MFI,WILLR,TRIX
# 197 starting RSI,CCI,MFI,WILLR,TRIX
# 77 finishing MACD,MACDSIGNAL,CCI,MFI
# 78 starting MACD,MACDSIGNAL,CCI,WILLR
# 197 finishing RSI,CCI,MFI,WILLR,TRIX
# 198 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI
# 78 finishing MACD,MACDSIGNAL,CCI,WILLR
# 79 starting MACD,MACDSIGNAL,CCI,TRIX
# 198 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI
# 199 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR
# 79 finishing MACD,MACDSIGNAL,CCI,TRIX
# 80 starting MACD,MACDSIGNAL,MFI,WILLR
# 199 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR
# 200 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,TRIX
# 80 finishing MACD,MACDSIGNAL,MFI,WILLR
# 81 starting MACD,MACDSIGNAL,MFI,TRIX
# 200 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,TRIX
# 201 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR
# 81 finishing MACD,MACDSIGNAL,MFI,TRIX
# 82 starting MACD,MACDSIGNAL,WILLR,TRIX
# 201 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR
# 202 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,TRIX
# 82 finishing MACD,MACDSIGNAL,WILLR,TRIX
# 83 starting ADX,CCI,MFI
# 202 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,TRIX
# 203 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 83 finishing ADX,CCI,MFI
# 84 starting ADX,CCI,WILLR
# 203 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 204 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR
# 84 finishing ADX,CCI,WILLR
# 85 starting ADX,CCI,TRIX
# 204 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR
# 205 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,TRIX
# 85 finishing ADX,CCI,TRIX
# 86 starting ADX,MFI,WILLR
# 86 finishing ADX,MFI,WILLR
# 87 starting ADX,MFI,TRIX
# 205 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,TRIX
# 206 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 87 finishing ADX,MFI,TRIX
# 88 starting ADX,WILLR,TRIX
# 206 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 207 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 88 finishing ADX,WILLR,TRIX
# 89 starting CCI,MFI,WILLR
# 207 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 208 starting STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR
# 89 finishing CCI,MFI,WILLR
# 90 starting CCI,MFI,TRIX
# 208 finishing STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR
# 209 starting STOCH_k,STOCH_D,ADX,CCI,MFI,TRIX
# 90 finishing CCI,MFI,TRIX
# 91 starting CCI,WILLR,TRIX
# 91 finishing CCI,WILLR,TRIX
# 92 starting MFI,WILLR,TRIX
# 209 finishing STOCH_k,STOCH_D,ADX,CCI,MFI,TRIX
# 210 starting STOCH_k,STOCH_D,ADX,CCI,WILLR,TRIX
# 92 finishing MFI,WILLR,TRIX
# 93 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX
# 210 finishing STOCH_k,STOCH_D,ADX,CCI,WILLR,TRIX
# 211 starting STOCH_k,STOCH_D,ADX,MFI,WILLR,TRIX
# 93 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX
# 94 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI
# 211 finishing STOCH_k,STOCH_D,ADX,MFI,WILLR,TRIX
# 212 starting STOCH_k,STOCH_D,CCI,MFI,WILLR,TRIX
# 94 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI
# 95 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI
# 212 finishing STOCH_k,STOCH_D,CCI,MFI,WILLR,TRIX
# 213 starting MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 95 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI
# 96 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR
# 213 finishing MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 214 starting MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 96 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,WILLR
# 97 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,TRIX
# 214 finishing MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 215 starting MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 97 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,TRIX
# 98 starting RSI,STOCH_k,STOCH_D,ADX,CCI
# 215 finishing MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 216 starting MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 98 finishing RSI,STOCH_k,STOCH_D,ADX,CCI
# 99 starting RSI,STOCH_k,STOCH_D,ADX,MFI
# 216 finishing MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 217 starting MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 99 finishing RSI,STOCH_k,STOCH_D,ADX,MFI
# 100 starting RSI,STOCH_k,STOCH_D,ADX,WILLR
# 217 finishing MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 218 starting ADX,CCI,MFI,WILLR,TRIX
# 100 finishing RSI,STOCH_k,STOCH_D,ADX,WILLR
# 101 starting RSI,STOCH_k,STOCH_D,ADX,TRIX
# 218 finishing ADX,CCI,MFI,WILLR,TRIX
# 219 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI
# 101 finishing RSI,STOCH_k,STOCH_D,ADX,TRIX
# 102 starting RSI,STOCH_k,STOCH_D,CCI,MFI
# 219 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI
# 220 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR
# 102 finishing RSI,STOCH_k,STOCH_D,CCI,MFI
# 103 starting RSI,STOCH_k,STOCH_D,CCI,WILLR
# 220 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR
# 221 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,TRIX
# 103 finishing RSI,STOCH_k,STOCH_D,CCI,WILLR
# 104 starting RSI,STOCH_k,STOCH_D,CCI,TRIX
# 221 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,TRIX
# 222 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR
# 104 finishing RSI,STOCH_k,STOCH_D,CCI,TRIX
# 105 starting RSI,STOCH_k,STOCH_D,MFI,WILLR
# 222 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR
# 223 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,TRIX
# 105 finishing RSI,STOCH_k,STOCH_D,MFI,WILLR
# 106 starting RSI,STOCH_k,STOCH_D,MFI,TRIX
# 223 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,TRIX
# 224 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 106 finishing RSI,STOCH_k,STOCH_D,MFI,TRIX
# 107 starting RSI,STOCH_k,STOCH_D,WILLR,TRIX
# 224 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR,TRIX
# 225 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR
# 107 finishing RSI,STOCH_k,STOCH_D,WILLR,TRIX
# 108 starting RSI,MACD,MACDSIGNAL,ADX,CCI
# 225 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR
# 226 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,TRIX
# 108 finishing RSI,MACD,MACDSIGNAL,ADX,CCI
# 109 starting RSI,MACD,MACDSIGNAL,ADX,MFI
# 109 finishing RSI,MACD,MACDSIGNAL,ADX,MFI
# 110 starting RSI,MACD,MACDSIGNAL,ADX,WILLR
# 226 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,TRIX
# 227 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 110 finishing RSI,MACD,MACDSIGNAL,ADX,WILLR
# 111 starting RSI,MACD,MACDSIGNAL,ADX,TRIX
# 227 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,WILLR,TRIX
# 228 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 111 finishing RSI,MACD,MACDSIGNAL,ADX,TRIX
# 112 starting RSI,MACD,MACDSIGNAL,CCI,MFI
# 228 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,MFI,WILLR,TRIX
# 229 starting RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR
# 112 finishing RSI,MACD,MACDSIGNAL,CCI,MFI
# 113 starting RSI,MACD,MACDSIGNAL,CCI,WILLR
# 229 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR
# 230 starting RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,TRIX
# 113 finishing RSI,MACD,MACDSIGNAL,CCI,WILLR
# 114 starting RSI,MACD,MACDSIGNAL,CCI,TRIX
# 230 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,TRIX
# 231 starting RSI,STOCH_k,STOCH_D,ADX,CCI,WILLR,TRIX
# 114 finishing RSI,MACD,MACDSIGNAL,CCI,TRIX
# 115 starting RSI,MACD,MACDSIGNAL,MFI,WILLR
# 231 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,WILLR,TRIX
# 232 starting RSI,STOCH_k,STOCH_D,ADX,MFI,WILLR,TRIX
# 115 finishing RSI,MACD,MACDSIGNAL,MFI,WILLR
# 116 starting RSI,MACD,MACDSIGNAL,MFI,TRIX
# 232 finishing RSI,STOCH_k,STOCH_D,ADX,MFI,WILLR,TRIX
# 233 starting RSI,STOCH_k,STOCH_D,CCI,MFI,WILLR,TRIX
# 116 finishing RSI,MACD,MACDSIGNAL,MFI,TRIX
# 117 starting RSI,MACD,MACDSIGNAL,WILLR,TRIX
# 233 finishing RSI,STOCH_k,STOCH_D,CCI,MFI,WILLR,TRIX
# 234 starting RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 117 finishing RSI,MACD,MACDSIGNAL,WILLR,TRIX
# 118 starting RSI,ADX,CCI,MFI
# 234 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 235 starting RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 118 finishing RSI,ADX,CCI,MFI
# 119 starting RSI,ADX,CCI,WILLR
# 235 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 236 starting RSI,MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 119 finishing RSI,ADX,CCI,WILLR
# 120 starting RSI,ADX,CCI,TRIX
# 236 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 237 starting RSI,MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 120 finishing RSI,ADX,CCI,TRIX
# 121 starting RSI,ADX,MFI,WILLR
# 237 finishing RSI,MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 238 starting RSI,MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 121 finishing RSI,ADX,MFI,WILLR
# 122 starting RSI,ADX,MFI,TRIX
# 238 finishing RSI,MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 239 starting RSI,ADX,CCI,MFI,WILLR,TRIX
# 122 finishing RSI,ADX,MFI,TRIX
# 123 starting RSI,ADX,WILLR,TRIX
# 239 finishing RSI,ADX,CCI,MFI,WILLR,TRIX
# 240 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 123 finishing RSI,ADX,WILLR,TRIX
# 124 starting RSI,CCI,MFI,WILLR
# 240 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 241 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 124 finishing RSI,CCI,MFI,WILLR
# 125 starting RSI,CCI,MFI,TRIX
# 125 finishing RSI,CCI,MFI,TRIX
# 126 starting RSI,CCI,WILLR,TRIX
# 241 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 242 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 126 finishing RSI,CCI,WILLR,TRIX
# 127 starting RSI,MFI,WILLR,TRIX
# 242 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 243 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 127 finishing RSI,MFI,WILLR,TRIX
# 128 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI
# 243 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 244 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 128 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI
# 244 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 245 starting STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR,TRIX
# 245 finishing STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR,TRIX
# 246 starting MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 246 finishing MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 247 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 247 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR
# 248 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 248 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,TRIX
# 249 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 249 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,WILLR,TRIX
# 250 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 250 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI,WILLR,TRIX
# 251 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 251 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WILLR,TRIX
# 252 starting RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR,TRIX
# 252 finishing RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR,TRIX
# 253 starting RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 253 finishing RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 254 starting STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 254 finishing STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 255 starting RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 255 finishing RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
#                                             indicators  \
# 0                                                  RSI
# 1              STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,MFI
# 2                                      STOCH_k,STOCH_D
# 3            STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,WILLR
# 4                                      MACD,MACDSIGNAL
# ..                                                 ...
# 250  RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,CCI,MFI,WI...
# 251         RSI,STOCH_k,STOCH_D,ADX,CCI,MFI,WILLR,TRIX
# 252         RSI,MACD,MACDSIGNAL,ADX,CCI,MFI,WILLR,TRIX
# 253  STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MFI,WI...
# 254  RSI,STOCH_k,STOCH_D,MACD,MACDSIGNAL,ADX,CCI,MF...
#
#      Total return (training)  Entries (training)  Return per entry (training)  \
# 0                    28.1596                 474                       0.0594
# 1                   151.1028                6607                       0.0229
# 2                     0.0000                   0                       0.0000
# 3                   208.8411                6382                       0.0327
# 4                   151.1783                6100                       0.0248
# ..                       ...                 ...                          ...
# 250                 214.0711                7807                       0.0274
# 251                 207.3954                9163                       0.0226
# 252                 251.0792                8473                       0.0296
# 253                 228.9523                8715                       0.0263
# 254                 262.4745                8777                       0.0299
#
#      Success (training)  Ratio (training)  Total of days (training)  \
# 0                 53.22              1.47                      1710
# 1                 51.84              1.14                      1710
# 2                 50.00             -1.00                      1710
# 3                 52.03              1.21                      1710
# 4                 51.74              1.15                      1710
# ..                  ...               ...                       ...
# 250               52.78              1.17                      1710
# 251               53.01              1.16                      1710
# 252               52.53              1.20                      1710
# 253               52.81              1.17                      1710
# 254               53.01              1.20                      1710
#
#      Total of months (training)  Monthly return (training)  \
# 0                       81.4286                     0.3458
# 1                       81.4286                     1.8556
# 2                       81.4286                     0.0000
# 3                       81.4286                     2.5647
# 4                       81.4286                     1.8566
# ..                          ...                        ...
# 250                     81.4286                     2.6289
# 251                     81.4286                     2.5470
# 252                     81.4286                     3.0834
# 253                     81.4286                     2.8117
# 254                     81.4286                     3.2234
#
#      Max drawdown (training)  ...  Return per entry (test)  Success (test)  \
# 0                    -9.2192  ...                   0.0734           59.26
# 1                   -35.5640  ...                   0.0015           50.50
# 2                     0.0000  ...                   0.0000           50.00
# 3                   -28.3920  ...                   0.0013           50.30
# 4                   -41.5622  ...                   0.0005           50.21
# ..                       ...  ...                      ...             ...
# 250                 -24.0587  ...                   0.0046           50.13
# 251                 -32.4440  ...                   0.0034           50.71
# 252                 -27.1024  ...                   0.0078           51.93
# 253                 -27.4419  ...                   0.0071           50.63
# 254                 -23.8416  ...                   0.0071           50.73
#
#      Ratio (test)  Total of days (test)  Total of months (test)  \
# 0            1.89                   414                 19.7143
# 1            1.01                   414                 19.7143
# 2           -1.00                   414                 19.7143
# 3            1.01                   414                 19.7143
# 4            1.00                   414                 19.7143
# ..            ...                   ...                     ...
# 250          1.04                   414                 19.7143
# 251          1.03                   414                 19.7143
# 252          1.07                   414                 19.7143
# 253          1.07                   414                 19.7143
# 254          1.07                   414                 19.7143
#
#      Monthly return (test)  Max drawdown (test)  Mean drawdown (test)  \
# 0                   0.3575              -2.0287               -0.1554
# 1                   0.2761             -34.4744              -15.5787
# 2                   0.0000              -0.0000                0.0000
# 3                   0.2283             -23.1691              -12.1237
# 4                   0.0940             -18.4589               -8.5263
# ..                     ...                  ...                   ...
# 250                 0.8039             -15.4579               -5.9071
# 251                 0.3332             -19.0035               -8.5242
# 252                 1.4493             -18.1632               -5.8093
# 253                 1.3250             -18.4218               -8.8253
# 254                 1.3288             -18.0068               -5.4158
#
#      Buy signals (test)  Sell signals (test)
# 0                    96                    0
# 1                  2381                 1157
# 2                     0                    0
# 3                  2484                 1099
# 4                  2370                 1169
# ..                  ...                  ...
# 250                1871                 1604
# 251                1519                  398
# 252                2080                 1569
# 253                2144                 1533
# 254                2093                 1598
#
# [255 rows x 25 columns]

# %%
lock = threading.Lock()
execute_test([['ADX','WILLR']], [], 0, lock, True)
# Out:
# 1 starting ADX,WILLR
#
# Strategy results %:
#
#  	Total return:  2.4076 %
#  	Entries:  13
#  	Return per entry:  0.1852 %
#  	Success:  81.82 %
#  	Ratio:  298.32
#  	Total of days:  414
#  	Total of months:  19.7143
#  	Monthly return:  0.1221 %
#  	Max drawdown:  -0.0082 %
#  	Mean drawdown:  -0.0016 %
#  	Buy signals 13
#  	Sell signals 0
#
# Strategy results:
#
#  	Total return:  2660.0
#  	Entries:  13
#  	Return per entry:  204.6154
#  	Success:  81.82 %
#  	Ratio:  267.0
#  	Total of days:  414
#  	Total of months:  19.7143
#  	Monthly return:  134.9275
#  	Max drawdown:  -10.0
#  	Mean drawdown:  -1.9147
#  	Buy signals 13
#  	Sell signals 0
# 1 finishing ADX,WILLR
